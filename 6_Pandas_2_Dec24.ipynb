# %% [markdown]
# <a href="https://colab.research.google.com/github/olakursri/DSML/blob/pandas/6_Pandas_2_Dec24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# !gdown 1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_
# To: /content/mckinsey.csv
# 100% 83.8k/83.8k [00:00<00:00, 79.0MB/s]

# %%
df = pd.read_csv('mckinsey.csv')
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.index = list(range(1, df.shape[0]+1))
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 1     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 2     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 3     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 4     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 5     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1701     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1702     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1703     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1704     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
new_row = {'country': 'India', 'year': 2025, 'population': 176545678, 'continent': 'Asia',
           'life_exp': 45.89, 'gdp_cap': 456.78}

df = pd.concat([df, pd.DataFrame([new_row])], ignore_index=True)
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2025   176545678      Asia    45.890  456.780000
#
# [1705 rows x 6 columns]

# %%
new_row = {'country': 'India', 'year': 2025, 'population': 18765678, 'continent': 'Asia',
           'life_exp': 45.89, 'gdp_cap': 456.78}
df.loc[len(df.index)] = new_row
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2025   176545678      Asia    45.890  456.780000
# 1705        India  2025    18765678      Asia    45.890  456.780000
#
# [1706 rows x 6 columns]

# %%
new_row = {'country': 'India', 'year': 2025, 'population': 18765678, 'continent': 'Asia',
           'life_exp': 45.89, 'gdp_cap': 456.78}
df.loc[len(df.index)] = new_row
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2025   176545678      Asia    45.890  456.780000
# 1705        India  2025    18765678      Asia    45.890  456.780000
# 1706        India  2025    18765678      Asia    45.890  456.780000
#
# [1707 rows x 6 columns]

# %%
df.iloc[len(df.index)-1] = ['Japan', 2024, 876789, 'Asia', 78.9, 678.9]
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2025   176545678      Asia    45.890  456.780000
# 1705        India  2025    18765678      Asia    45.890  456.780000
# 1706        Japan  2024      876789      Asia    78.900  678.900000
#
# [1707 rows x 6 columns]

# %%
df = df.drop(1706, axis=0)
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2025   176545678      Asia    45.890  456.780000
# 1705        India  2025    18765678      Asia    45.890  456.780000
#
# [1706 rows x 6 columns]

# %%
df.drop([1704, 1705], axis=0, inplace=True)

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.index = list(range(1, df.shape[0]+1))
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 1     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 2     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 3     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 4     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 5     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1701     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1702     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1703     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1704     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.reset_index(drop=True, inplace=True) # reset the index to 0....1704

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
# Handling Duplicate Records

# %%
new_row = {'country': 'India', 'year': 2025, 'population': 18765678, 'continent': 'Asia',
           'life_exp': 45.89, 'gdp_cap': 456.78}
df.loc[len(df.index)] = new_row
df.loc[len(df.index)] = new_row
df.loc[len(df.index)] = ['Japan', 2024, 876789, 'Asia', 78.9, 678.9]
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2025    18765678      Asia    45.890  456.780000
# 1705        India  2025    18765678      Asia    45.890  456.780000
# 1706        Japan  2024      876789      Asia    78.900  678.900000
#
# [1707 rows x 6 columns]

# %%
df.loc[len(df.index)] = ['Afghanistan',	1952,	8425333,	'Asia',	28.801,	779.445314]
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2025    18765678      Asia    45.890  456.780000
# 1705        India  2025    18765678      Asia    45.890  456.780000
# 1706        Japan  2024      876789      Asia    78.900  678.900000
# 1707  Afghanistan  1952     8425333      Asia    28.801  779.445314
#
# [1708 rows x 6 columns]

# %%
df.loc[len(df.index)] = ['Afghanistan',	1952,	8425333,	'Asia',	28.801,	779.445314]
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1704        India  2025    18765678      Asia    45.890  456.780000
# 1705        India  2025    18765678      Asia    45.890  456.780000
# 1706        Japan  2024      876789      Asia    78.900  678.900000
# 1707  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1708  Afghanistan  1952     8425333      Asia    28.801  779.445314
#
# [1709 rows x 6 columns]

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1704    False
# 1705     True
# 1706    False
# 1707    False
# 1708     True
# Length: 1709, dtype: bool

# %%
df.loc[df.duplicated()]
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 1705        India  2025    18765678      Asia    45.890  456.780000
# 1708  Afghanistan  1952     8425333      Asia    28.801  779.445314

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2025    18765678      Asia    45.890  456.780000
# 1706        Japan  2024      876789      Asia    78.900  678.900000
# 1707  Afghanistan  1952     8425333      Asia    28.801  779.445314
#
# [1707 rows x 6 columns]

# %%
df.reset_index(drop=True, inplace=True)
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2025    18765678      Asia    45.890  456.780000
# 1705        Japan  2024      876789      Asia    78.900  678.900000
# 1706  Afghanistan  1952     8425333      Asia    28.801  779.445314
#
# [1707 rows x 6 columns]

# %%
data = {'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
        'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
        'C': ['small', 'large', 'large', 'small', 'small', 'large', 'large', 'small'],
        'D': [1, 2, 2, 3, 3, 4, 5, 6]}

df1 = pd.DataFrame(data)
df1
# Out:
#      A      B      C  D
# 0  foo    one  small  1
# 1  bar    one  large  2
# 2  foo    two  large  2
# 3  bar  three  small  3
# 4  foo    two  small  3
# 5  bar    two  large  4
# 6  foo    one  large  5
# 7  foo  three  small  6

# %%
print(sum(df1.duplicated(subset=['A', 'B'])))
# Out:
# 2

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2025    18765678      Asia    45.890  456.780000
# 1705        Japan  2024      876789      Asia    78.900  678.900000
# 1706  Afghanistan  1952     8425333      Asia    28.801  779.445314
#
# [1707 rows x 6 columns]

# %%
df.index = list(range(1, df.shape[0]+1))
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 1     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 2     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 3     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 4     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 5     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1703     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1704     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1705        India  2025    18765678      Asia    45.890  456.780000
# 1706        Japan  2024      876789      Asia    78.900  678.900000
# 1707  Afghanistan  1952     8425333      Asia    28.801  779.445314
#
# [1707 rows x 6 columns]

# %%
df.iloc[0:4, 1:3]
# Out:
#    year  population
# 1  1952     8425333
# 2  1957     9240934
# 3  1962    10267083
# 4  1967    11537966

# %%
df.loc[1:4, 1:5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-6bb7d4c12e6f> in <cell line: 0>()
# ----> 1 df.loc[1:4, 1:5]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1182             if self._is_scalar_access(key):
#    1183                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184             return self._getitem_tuple(key)
#    1185         else:
#    1186             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1375             return self._multi_take(tup)
#    1376
# -> 1377         return self._getitem_tuple_same_dim(tup)
#    1378
#    1379     def _get_label(self, label, axis: AxisInt):
#
# ...

# %%
df.loc[1:4, 'country': 'continent']
# Out:
#        country  year  population continent
# 1  Afghanistan  1952     8425333      Asia
# 2  Afghanistan  1957     9240934      Asia
# 3  Afghanistan  1962    10267083      Asia
# 4  Afghanistan  1967    11537966      Asia

# %%
df.loc[1:4, ['country', 'continent']]
# Out:
#        country continent
# 1  Afghanistan      Asia
# 2  Afghanistan      Asia
# 3  Afghanistan      Asia
# 4  Afghanistan      Asia

# %%
# Aggregate Functions

# %%
le = df['life_exp']
le
# Out:
# 1       28.801
# 2       30.332
# 3       31.997
# 4       34.020
# 5       36.088
#          ...
# 1703    39.989
# 1704    43.487
# 1705    45.890
# 1706    78.900
# 1707    28.801
# Name: life_exp, Length: 1707, dtype: float64

# %%
print(le.mean())
# Out:
# 59.45989202108963

# %%
le.max()
# Out:
# 82.603

# %%
le.min()
# Out:
# 23.599

# %%
le.sum()
# Out:
# np.float64(101498.03568)

# %%
# Sorting  values

# %%
df.describe()
# Out:
#               year    population     life_exp        gdp_cap
# count  1707.000000  1.707000e+03  1707.000000    1707.000000
# mean   1979.536614  2.956563e+07    59.459892    7203.768290
# std      17.331579  1.060684e+08    12.939819    9852.639350
# min    1952.000000  6.001100e+04    23.599000     241.165876
# 25%    1964.500000  2.792776e+06    48.143000    1194.939659
# 50%    1982.000000  7.026113e+06    60.660000    3528.481305
# 75%    1997.000000  1.956179e+07    70.846000    9319.503534
# max    2025.000000  1.318683e+09    82.603000  113523.132900

# %%
df.sort_values(['life_exp'])
# Out:
#                country  year  population continent  life_exp       gdp_cap
# 1293            Rwanda  1992     7290203    Africa    23.599    737.068595
# 1          Afghanistan  1952     8425333      Asia    28.801    779.445314
# 1707       Afghanistan  1952     8425333      Asia    28.801    779.445314
# 553             Gambia  1952      284320    Africa    30.000    485.230659
# 37              Angola  1952     4232095    Africa    30.015   3520.610273
# ...                ...   ...         ...       ...       ...           ...
# 1488       Switzerland  2007     7554661    Europe    81.701  37506.419070
# 696            Iceland  2007      301931    Europe    81.757  36180.789190
# 803              Japan  2002   127065841      Asia    82.000  28604.591900
# 672   Hong Kong, China  2007     6980412      Asia    82.208  39724.978670
# 804              Japan  2007   127467972      Asia    82.603  31656.068060
#
# [1707 rows x 6 columns]

# %%
df.sort_values(['life_exp'], ascending=False)
# Out:
#                country  year  population continent  life_exp       gdp_cap
# 804              Japan  2007   127467972      Asia    82.603  31656.068060
# 672   Hong Kong, China  2007     6980412      Asia    82.208  39724.978670
# 803              Japan  2002   127065841      Asia    82.000  28604.591900
# 696            Iceland  2007      301931    Europe    81.757  36180.789190
# 1488       Switzerland  2007     7554661    Europe    81.701  37506.419070
# ...                ...   ...         ...       ...       ...           ...
# 37              Angola  1952     4232095    Africa    30.015   3520.610273
# 553             Gambia  1952      284320    Africa    30.000    485.230659
# 1          Afghanistan  1952     8425333      Asia    28.801    779.445314
# 1707       Afghanistan  1952     8425333      Asia    28.801    779.445314
# 1293            Rwanda  1992     7290203    Africa    23.599    737.068595
#
# [1707 rows x 6 columns]

# %%
df.sort_values(['year', 'life_exp'])
# Out:
#                country  year  population continent  life_exp       gdp_cap
# 1          Afghanistan  1952     8425333      Asia    28.801    779.445314
# 1707       Afghanistan  1952     8425333      Asia    28.801    779.445314
# 553             Gambia  1952      284320    Africa    30.000    485.230659
# 37              Angola  1952     4232095    Africa    30.015   3520.610273
# 1345      Sierra Leone  1952     2143249    Africa    30.331    879.787736
# ...                ...   ...         ...       ...       ...           ...
# 696            Iceland  2007      301931    Europe    81.757  36180.789190
# 672   Hong Kong, China  2007     6980412      Asia    82.208  39724.978670
# 804              Japan  2007   127467972      Asia    82.603  31656.068060
# 1706             Japan  2024      876789      Asia    78.900    678.900000
# 1705             India  2025    18765678      Asia    45.890    456.780000
#
# [1707 rows x 6 columns]

# %%
df.sort_values(['year', 'life_exp'], ascending=[True, False])
# Out:
#           country  year  population continent  life_exp       gdp_cap
# 1141       Norway  1952     3327728    Europe    72.670  10095.421720
# 685       Iceland  1952      147962    Europe    72.490   7267.688428
# 1081  Netherlands  1952    10381988    Europe    72.130   8941.571858
# 1465       Sweden  1952     7124673    Europe    71.860   8527.844662
# 409       Denmark  1952     4334000    Europe    70.780   9692.385245
# ...           ...   ...         ...       ...       ...           ...
# 1692       Zambia  2007    11746035    Africa    42.384   1271.211593
# 1044   Mozambique  2007    19951656    Africa    42.082    823.685621
# 1464    Swaziland  2007     1133066    Africa    39.613   4513.480643
# 1706        Japan  2024      876789      Asia    78.900    678.900000
# 1705        India  2025    18765678      Asia    45.890    456.780000
#
# [1707 rows x 6 columns]

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 1     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 2     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 3     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 4     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 5     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1703     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1704     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1705        India  2025    18765678      Asia    45.890  456.780000
# 1706        Japan  2024      876789      Asia    78.900  678.900000
# 1707  Afghanistan  1952     8425333      Asia    28.801  779.445314
#
# [1707 rows x 6 columns]

# %%
users = pd.DataFrame({'userid': [1, 2, 3], 'name': ['abhinav', 'satish', 'Deepthi']})
users
# Out:
#    userid     name
# 0       1  abhinav
# 1       2   satish
# 2       3  Deepthi

# %%
msgs = pd.DataFrame({'userid': [1, 1, 2, 4], 'msg': ['hello', 'hi', 'hey', 'bye']})
msgs
# Out:
#    userid    msg
# 0       1  hello
# 1       1     hi
# 2       2    hey
# 3       4    bye

# %%
pd.concat([users, msgs])
# Out:
#    userid     name    msg
# 0       1  abhinav    NaN
# 1       2   satish    NaN
# 2       3  Deepthi    NaN
# 0       1      NaN  hello
# 1       1      NaN     hi
# 2       2      NaN    hey
# 3       4      NaN    bye

# %%
pd.concat([users, msgs], ignore_index=True)
# Out:
#    userid     name    msg
# 0       1  abhinav    NaN
# 1       2   satish    NaN
# 2       3  Deepthi    NaN
# 3       1      NaN  hello
# 4       1      NaN     hi
# 5       2      NaN    hey
# 6       4      NaN    bye

# %%
pd.concat([users, msgs], axis=1)
# Out:
#    userid     name  userid    msg
# 0     1.0  abhinav       1  hello
# 1     2.0   satish       1     hi
# 2     3.0  Deepthi       2    hey
# 3     NaN      NaN       4    bye

# %%
type(np.nan)
# Out:
# float

# %%
users.merge(msgs, on='userid')
# Out:
#    userid     name    msg
# 0       1  abhinav  hello
# 1       1  abhinav     hi
# 2       2   satish    hey

# %%
users.merge(msgs, on='userid', how='left')
# Out:
#    userid     name    msg
# 0       1  abhinav  hello
# 1       1  abhinav     hi
# 2       2   satish    hey
# 3       3  Deepthi    NaN

# %%
users.merge(msgs, on='userid', how='right')
# Out:
#    userid     name    msg
# 0       1  abhinav  hello
# 1       1  abhinav     hi
# 2       2   satish    hey
# 3       4      NaN    bye

# %%
users.merge(msgs, on='userid', how='outer')
# Out:
#    userid     name    msg
# 0       1  abhinav  hello
# 1       1  abhinav     hi
# 2       2   satish    hey
# 3       3  Deepthi    NaN
# 4       4      NaN    bye

# %%
users.rename(columns={'userid': 'id'}, inplace=True)
users
# Out:
#    id     name
# 0   1  abhinav
# 1   2   satish
# 2   3  Deepthi

# %%
msgs
# Out:
#    userid    msg
# 0       1  hello
# 1       1     hi
# 2       2    hey
# 3       4    bye

# %%
users.merge(msgs, left_on='id', right_on='userid')
# Out:
#    id     name  userid    msg
# 0   1  abhinav       1  hello
# 1   1  abhinav       1     hi
# 2   2   satish       2    hey

# %%
import pandas as pd
df1 = pd.DataFrame({'A':[10,30], 'B':[20,40], 'C':[30, 60]})
df2 = pd.DataFrame({'A':[10,40], 'C':[30, 60]})
# df2.merge(df1, on = 'A', how = 'outer')
df1
# Out:
#     A   B   C
# 0  10  20  30
# 1  30  40  60

# %%
df2
# Out:
#     A   C
# 0  10  30
# 1  40  60

# %%
df2.merge(df1, on = 'A', how = 'outer')
# Out:
#     A  C_x   B  C_y
# 0  10   30  20   30
# 1  30   60  40   60

# %%
df2.merge(df1, on='A')
# Out:
#     A  C_x   B  C_y
# 0  10   30  20   30

# %%
df2.merge(df1, on=['A', 'C'])
# Out:
#     A   C   B
# 0  10  30  20
